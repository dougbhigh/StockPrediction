# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\jhoff\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (1.18.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (7.12.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (45.2.0.post20200210)
# Collecting plotly>=4.1.1
#   Downloading plotly-4.12.0-py2.py3-none-any.whl (13.1 MB)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (7.5.1)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (1.14.0)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\jhoff\anaconda3\lib\site-packages (from cufflinks) (1.0.1)
# Requirement already satisfied: pygments in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.5.2)
# Requirement already satisfied: backcall in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.14.1)
# Requirement already satisfied: pickleshare in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.3)
# Requirement already satisfied: decorator in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.4.1)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.3)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jhoff\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (4.3.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\jhoff\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jhoff\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jhoff\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.1.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jhoff\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\jhoff\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\jhoff\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2019.3)
# Requirement already satisfied: parso>=0.5.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->cufflinks) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\jhoff\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.1.8)
# Requirement already satisfied: ipython-genutils in c:\users\jhoff\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.2.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\jhoff\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\jhoff\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\jhoff\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.0.3)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\jhoff\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (227)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.0.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\jhoff\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (18.1.1)
# Requirement already satisfied: nbconvert in c:\users\jhoff\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (5.6.1)
# Requirement already satisfied: jinja2 in c:\users\jhoff\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.1)
# Requirement already satisfied: Send2Trash in c:\users\jhoff\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\jhoff\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.3)
# Requirement already satisfied: prometheus-client in c:\users\jhoff\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jhoff\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.3)
# Requirement already satisfied: bleach in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: testpath in c:\users\jhoff\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jhoff\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.1.1)
# Requirement already satisfied: webencodings in c:\users\jhoff\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 3.10.0
#     Uninstalling plotly-3.10.0:
#       Successfully uninstalled plotly-3.10.0
# Successfully installed plotly-4.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df = pd.read_csv('AAPL Historical Data.csv')

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Price'])])

fig.show()
# Out:
# <div>
#
#
#             <div id="1643fe4a-da83-48ea-92eb-1844eee1871a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("

# Requirement already satisfied: retrying>=1.3.3 in c:\users\jhoff\anaconda3\lib\site-packages (from plotly==3.10.0) (1.3.3)
# Requirement already satisfied: pytz in c:\users\jhoff\anaconda3\lib\site-packages (from plotly==3.10.0) (2019.3)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\jhoff\anaconda3\lib\site-packages (from plotly==3.10.0) (4.4.1)
# Requirement already satisfied: six in c:\users\jhoff\anaconda3\lib\site-packages (from plotly==3.10.0) (1.14.0)
# Requirement already satisfied: requests in c:\users\jhoff\anaconda3\lib\site-packages (from plotly==3.10.0) (2.22.0)
# Requirement already satisfied: ipython-genutils in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly==3.10.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly==3.10.0) (3.2.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly==3.10.0) (4.3.3)
# Requirement already satisfied: jupyter-core in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly==3.10.0) (4.6.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->plotly==3.10.0) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->plotly==3.10.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->plotly==3.10.0) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->plotly==3.10.0) (2.8)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==3.10.0) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==3.10.0) (19.3.0)
# Requirement already satisfied: setuptools in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==3.10.0) (45.2.0.post20200210)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==3.10.0) (2.0.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\jhoff\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2->plotly==3.10.0) (227)
# Requirement already satisfied: zipp>=0.5 in c:\users\jhoff\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==3.10.0) (2.2.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.11.0
#     Uninstalling plotly-4.11.0:
#       Successfully uninstalled plotly-4.11.0
# Successfully installed plotly-3.10.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: cufflinks 0.17.3 has requirement plotly>=4.1.1, but you'll have plotly 3.10.0 which is incompatible.

# %%
pip install chart-studio
# Out:
# Requirement already satisfied: chart-studio in c:\users\jhoff\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\jhoff\anaconda3\lib\site-packages (from chart-studio) (1.3.3)
# Requirement already satisfied: six in c:\users\jhoff\anaconda3\lib\site-packages (from chart-studio) (1.14.0)
# Requirement already satisfied: requests in c:\users\jhoff\anaconda3\lib\site-packages (from chart-studio) (2.22.0)
# Requirement already satisfied: plotly in c:\users\jhoff\anaconda3\lib\site-packages (from chart-studio) (3.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->chart-studio) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->chart-studio) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->chart-studio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhoff\anaconda3\lib\site-packages (from requests->chart-studio) (2019.11.28)
# Requirement already satisfied: nbformat>=4.2 in c:\users\jhoff\anaconda3\lib\site-packages (from plotly->chart-studio) (5.0.4)
# Requirement already satisfied: pytz in c:\users\jhoff\anaconda3\lib\site-packages (from plotly->chart-studio) (2019.3)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\jhoff\anaconda3\lib\site-packages (from plotly->chart-studio) (4.4.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->chart-studio) (4.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->chart-studio) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->chart-studio) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\jhoff\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->chart-studio) (4.6.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->chart-studio) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->chart-studio) (0.15.7)
# Requirement already satisfied: setuptools in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->chart-studio) (45.2.0.post20200210)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\jhoff\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->chart-studio) (2.0.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\jhoff\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2->plotly->chart-studio) (227)
# Requirement already satisfied: zipp>=0.5 in c:\users\jhoff\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly->chart-studio) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
from datetime import datetime
import numpy as np
import pandas as pd
import plotly.plotly as py

# %%
df = data.DataReader("gs", 'yahoo', datetime(2008, 1, 1), datetime(2008, 12, 28))
df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2008-01-02  215.050003  206.600006  214.800003  207.600006   9573500.0
# 2008-01-03  209.039993  204.139999  208.919998  204.839996   7751700.0
# 2008-01-04  204.000000  198.289993  201.000000  199.929993  10157900.0
# 2008-01-07  200.250000  189.990005  200.229996  194.729996  16044400.0
# 2008-01-08  199.500000  189.000000  195.809998  189.500000  13553700.0
# ...                ...         ...         ...         ...         ...
# 2008-12-19   80.730003   77.650002   79.370003   80.730003  20379300.0
# 2008-12-22   80.129997   74.889999   80.000000   77.000000  13175500.0
# 2008-12-23   78.000000   75.050003   77.410004   75.199997   9468000.0
# 2008-12-24   76.739998   75.260002   75.540001   76.440002   3166000.0
# 2008-12-26   77.440002   75.309998   76.830002   75.970001   4657300.0
#
#              Adj Close
# Date
# 2008-01-02  173.751434
# 2008-01-03  171.441467
# 2008-01-04  167.332047
# 2008-01-07  162.979858
# 2008-01-08  158.602631
# ...                ...
# 2008-12-19   68.151100
# 2008-12-22   65.002266
# 2008-12-23   63.482746
# 2008-12-24   64.529549
# 2008-12-26   64.132767
#
# [250 rows x 6 columns]

# %%
INCREASING_COLOR = '#17BECF'
DECREASING_COLOR = '#7F7F7F'

# %%
data = [ dict(
    type = 'candlestick',
    open = df.Open,
    high = df.High,
    low = df.Low,
    close = df.Close,
    x = df.index,
    yaxis = 'y2',
    name = 'GS',
    increasing = dict( line = dict( color = INCREASING_COLOR ) ),
    decreasing = dict( line = dict( color = DECREASING_COLOR ) ),
) ]

layout=dict()

fig = dict( data=data, layout=layout )

# %%
fig['layout'] = dict()
fig['layout']['plot_bgcolor'] = 'rgb(250, 250, 250)'
fig['layout']['xaxis'] = dict( rangeselector = dict( visible = True ) )
fig['layout']['yaxis'] = dict( domain = [0, 0.2], showticklabels = False )
fig['layout']['yaxis2'] = dict( domain = [0.2, 0.8] )
fig['layout']['legend'] = dict( orientation = 'h', y=0.9, x=0.3, yanchor='bottom' )
fig['layout']['margin'] = dict( t=40, b=40, r=40, l=40 )

# %%
rangeselector=dict(
    visibe = True,
    x = 0, y = 0.9,
    bgcolor = 'rgba(150, 200, 250, 0.4)',
    font = dict( size = 13 ),
    buttons=list([
        dict(count=1,
             label='reset',
             step='all'),
        dict(count=1,
             label='1yr',
             step='year',
             stepmode='backward'),
        dict(count=3,
            label='3 mo',
            step='month',
            stepmode='backward'),
        dict(count=1,
            label='1 mo',
            step='month',
            stepmode='backward'),
        dict(step='all')
    ]))
    
fig['layout']['xaxis']['rangeselector'] = rangeselector

# %%
def movingaverage(interval, window_size=10):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')

# %%
mv_y = movingaverage(df.Close)
mv_x = list(df.index)

# Clip the ends
mv_x = mv_x[5:-5]
mv_y = mv_y[5:-5]

fig['data'].append( dict( x=mv_x, y=mv_y, type='scatter', mode='lines', 
                         line = dict( width = 1 ),
                         marker = dict( color = '#E377C2' ),
                         yaxis = 'y2', name='Moving Average' ) )

# %%
colors = []

for i in range(len(df.Close)):
    if i != 0:
        if df.Close[i] > df.Close[i-1]:
            colors.append(INCREASING_COLOR)
        else:
            colors.append(DECREASING_COLOR)
    else:
        colors.append(DECREASING_COLOR)

# %%
fig['data'].append( dict( x=df.index, y=df.Volume,                         
                         marker=dict( color=colors ),
                         type='bar', yaxis='y', name='Volume' ) )

# %%
def bbands(price, window_size=10, num_of_std=5):
    rolling_mean = price.rolling(window=window_size).mean()
    rolling_std  = price.rolling(window=window_size).std()
    upper_band = rolling_mean + (rolling_std*num_of_std)
    lower_band = rolling_mean - (rolling_std*num_of_std)
    return rolling_mean, upper_band, lower_band

bb_avg, bb_upper, bb_lower = bbands(df.Close)

fig['data'].append( dict( x=df.index, y=bb_upper, type='scatter', yaxis='y2', 
                         line = dict( width = 1 ),
                         marker=dict(color='#ccc'), hoverinfo='none', 
                         legendgroup='Bollinger Bands', name='Bollinger Bands') )

fig['data'].append( dict( x=df.index, y=bb_lower, type='scatter', yaxis='y2',
                         line = dict( width = 1 ),
                         marker=dict(color='#ccc'), hoverinfo='none',
                         legendgroup='Bollinger Bands', showlegend=False ) )

# %%
import chart_studio.plotly as py

# %%
py.iplot( fig, filename = 'candlestick-test-3', validate = False )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-5635a863e040> in <module>
# ----> 1 py.iplot( fig, filename = 'candlestick-test-3', validate = False )
#
# ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     133     if "auto_open" not in plot_options:
#     134         plot_options["auto_open"] = False
# --> 135     url = plot(figure_or_data, **plot_options)
#     136
#     137     if isinstance(figure_or_data, dict):
#
# ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     263
#     264     # Extract grid
# --> 265     figure, grid = _extract_grid_from_fig_like(figure)
#     266
#     267     # Upload grid if anything was extracted
#
# ~\anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in _extract_grid_from_fig_like(fig, grid, path)
#    1863         if trace_type not in reference_traces:
#    1864             reference_traces[trace_type] = reference_fig.add_trace(
# -> 1865                 {"type": trace_type}
#    1866             ).data[-1]
#    1867
#
# AttributeError: 'Candlestick' object has no attribute 'data'
